# %%
from BIOSSESDataset import BIOSSESDataset

# %%
dataset = BIOSSESDataset()
# Out:
# ['It has recently become evident that Craf is essential for the onset of Kras-driven non-small cell lung cancer.']

# %%
df = dataset.get_dataframe()
df
# Out:
#                                            Sentence 1  \
# 0   It has recently been shown that Craf is essent...
# 1   The Bcl-2 inhibitor ABT-737 induces regression...
# 2   Previous studies demonstrated that the decreas...
# 3   More recently, IDH mutations and resultant 2-h...
# 4   Recent in vitro studies using shRNA-based appr...
# ..                                                ...
# 95  Ironically, Rest has recently been described a...
# 96  Alterations in Oct-4 expression promote differ...
# 97  Three programs, PicTar, miRanda, and TargetSca...
# 98  The recent reports demonstrated that the first...
# 99     Oncogenic KRAS mutations are common in cancer.
#
#                                            Sentence 2
# 0   It has recently become evident that Craf is es...
# 1   Recently, it has been reported that ABT-737 is...
# 2   In addition, genetic and functional studies su...
# 3   It has also been recently reported that mutati...
# 4   Two recent studies used RNAi-mediated Tet2 kno...
# ..                                                ...
# 95  In human epithelial cells REST has been descri...
# 96  OCT4, a transcript of POU5F1, plays a role in ...
# 97  The genes that decreased 2-fold or more were f...
# 98  Mismatches near the 5′ end of the small RNA co...
# 99  Notably, c-Raf has recently been found essenti...
#
# [100 rows x 2 columns]

# %%
sample = df.iloc[1]
sample
# Out:
# Sentence 1    The Bcl-2 inhibitor ABT-737 induces regression...
# Sentence 2    Recently, it has been reported that ABT-737 is...
# Name: 1, dtype: object

# %%
sample["Sentence 1"]
# Out:
# 'The Bcl-2 inhibitor ABT-737 induces regression of solid tumors  and its derivatives are in the early clinical phase as cancer therapeutics; however, it targets Bcl-2, Bcl-XL, and Bcl-w, but not Mcl-1, which induces resistance against apoptotic cell death triggered by ABT-737.'

# %%
for row in df[:]:
    print(row)
# Out:
# Sentence 1
# Sentence 2

# %%
for row in df.iterrows():
    print(row)
# Out:
# (0, Sentence 1    It has recently been shown that Craf is essent...
# Sentence 2    It has recently become evident that Craf is es...
# Name: 0, dtype: object)
# (1, Sentence 1    The Bcl-2 inhibitor ABT-737 induces regression...
# Sentence 2    Recently, it has been reported that ABT-737 is...
# Name: 1, dtype: object)
# (2, Sentence 1    Previous studies demonstrated that the decreas...
# Sentence 2    In addition, genetic and functional studies su...
# Name: 2, dtype: object)
# (3, Sentence 1    More recently, IDH mutations and resultant 2-h...
# Sentence 2    It has also been recently reported that mutati...
# Name: 3, dtype: object)
# (4, Sentence 1    Recent in vitro studies using shRNA-based appr...
# Sentence 2    Two recent studies used RNAi-mediated Tet2 kno...
# Name: 4, dtype: object)
# (5, Sentence 1    Recently, it was reported that expression of I...
# Sentence 2    This large-scale study showed that IDH1/IDH2 m...
# Name: 5, dtype: object)
# (6, Sentence 1    Recently, it was reported that expression of I...
# Sentence 2    the mechanism was clarified by yet another gen...
# Name: 6, dtype: object)
# (7, Sentence 1    expression of an activated form of Ras protein...
# Sentence 2    When expressed alone in primary cells however,...
# Name: 7, dtype: object)
# (8, Sentence 1    A high percentage of tumor cells that take on ...
# Sentence 2    As a serine/threonine protein kinase, AKT func...
# Name: 8, dtype: object)
# (9, Sentence 1    n view of the evidence that many tumors occurr...
# Sentence 2    The phenomena of neoplastic development and ne...
# Name: 9, dtype: object)
# (10, Sentence 1    The phenomena of neoplastic development and ne...
# Sentence 2    Neoplastic development represents cumulative g...
# Name: 10, dtype: object)
# (11, Sentence 1    Tumorigenesis is a multistage process that inv...
# Sentence 2    Previous studies have suggested a number of ha...
# Name: 11, dtype: object)
# (12, Sentence 1    Furthermore, transiently expressed exogenous L...
# Sentence 2    LATS1 and LATS2 have been detected on interpha...
# Name: 12, dtype: object)
# (13, Sentence 1    Since in S. cerevisiae DBF2 was shown to be as...
# Sentence 2    Taking into consideration the role that DBF2 h...
# Name: 13, dtype: object)
# (14, Sentence 1    Several computational target prediction approa...
# Sentence 2    Three programs, PicTar, miRanda, and TargetSca...
# Name: 14, dtype: object)
# (15, Sentence 1    Several lines of evidence suggest that the kno...
# Sentence 2    In individual human tumor specimens, these pri...
# Name: 15, dtype: object)
# (16, Sentence 1    The Retinoblastoma protein, pRb, was among the...
# Sentence 2    Mutation of the retinoblastoma tumor susceptib...
# Name: 16, dtype: object)
# (17, Sentence 1    For example, loss of, or functional alteration...
# Sentence 2    E2F1 stabilizes p53 by inducing the expression...
# Name: 17, dtype: object)
# (18, Sentence 1    Recently, miR-126 was identified as a metastas...
# Sentence 2    Subsequent reports showed that miR-126 targete...
# Name: 18, dtype: object)
# (19, Sentence 1    Recently, miR-126 was identified as a metastas...
# Sentence 2    MiR-155 is upregulated in several human tumors...
# Name: 19, dtype: object)
# (20, Sentence 1    Up-regulation of miR-24 has been observed in a...
# Sentence 2    In addition, miR-24 is one of the most abundan...
# Name: 20, dtype: object)
# (21, Sentence 1    MiR-223 seems to be a target molecule of TFs r...
# Sentence 2    Feedback loops in which a miRNA-regulated tran...
# Name: 21, dtype: object)
# (22, Sentence 1    Furthermore, a very recent study demonstrated ...
# Sentence 2    miR-223 regulates granulopoiesis by a feedback...
# Name: 22, dtype: object)
# (23, Sentence 1    miR-223 regulates granulopoiesis by a feedback...
# Sentence 2    There is growing evidence from animal systems ...
# Name: 23, dtype: object)
# (24, Sentence 1    In myelopoiesis, miR-223 has been shown to reg...
# Sentence 2    As shown previously, miR-223 is highly conserv...
# Name: 24, dtype: object)
# (25, Sentence 1    To clarify the roles of miRNAs in erythropoies...
# Sentence 2    In myelopoiesis, miR-223 has been shown to reg...
# Name: 25, dtype: object)
# (26, Sentence 1    We then sought to reassess the regulation of m...
# Sentence 2    Importantly, our reassessment revealed that th...
# Name: 26, dtype: object)
# (27, Sentence 1    Unique segments of homologous sequences in RIP...
# Sentence 2             RIP1 was reported to interact with RIP3.
# Name: 27, dtype: object)
# (28, Sentence 1    This form of necrosis, also termed necroptosis...
# Sentence 2    TNF-mediated programmed necrosis typically inv...
# Name: 28, dtype: object)
# (29, Sentence 1    This form of necrosis, also termed necroptosis...
# Sentence 2    Moreover, other reports have also shown that n...
# Name: 29, dtype: object)
# (30, Sentence 1    Furthermore, ablation of both Erk1 and Erk2 im...
# Sentence 2    Only concomitant ablation of ERK1 and ERK2 imp...
# Name: 30, dtype: object)
# (31, Sentence 1    Importantly, the role of ERK phosphorylation i...
# Sentence 2    As mentioned above, high ERK activity is cruci...
# Name: 31, dtype: object)
# (32, Sentence 1    Lung tumour formation in mice by oncogenic KRA...
# Sentence 2    The oncogenic activity of mutant Kras appears ...
# Name: 32, dtype: object)
# (33, Sentence 1    The oncogenic activity of mutant Kras appears ...
# Sentence 2    Notably, c-Raf has recently been found essenti...
# Name: 33, dtype: object)
# (34, Sentence 1    The oncogenic activity of mutant Kras appears ...
# Sentence 2       Oncogenic KRAS mutations are common in cancer.
# Name: 34, dtype: object)
# (35, Sentence 1    BAF53 and β-actin subunits have been implicate...
# Sentence 2    In addition, Arp4-related BAF53 and β-actin ar...
# Name: 35, dtype: object)
# (36, Sentence 1    The mammalian Arp, BAF53 (BRG-associated facto...
# Sentence 2    In addition, Arp4-related BAF53 and β-actin ar...
# Name: 36, dtype: object)
# (37, Sentence 1    All known GEFs reconfigure the nucleotide-bind...
# Sentence 2    A characteristic of GEFs is their strong prefe...
# Name: 37, dtype: object)
# (38, Sentence 1    In eukaryotic cells, small G-proteins are crit...
# Sentence 2    Eukaryotic small G-proteins are often controll...
# Name: 38, dtype: object)
# (39, Sentence 1    In a previous study in a mouse model of KRas-d...
# Sentence 2    Previous results showed that oncogenic Ras ele...
# Name: 39, dtype: object)
# (40, Sentence 1    Importantly, RNAi knockdown of Gfpt1 reduced o...
# Sentence 2    GFPT1 is the rate-limiting enzyme in the HBP a...
# Name: 40, dtype: object)
# (41, Sentence 1    We, and others, have recently described the in...
# Sentence 2    There is a certain variability in these findin...
# Name: 41, dtype: object)
# (42, Sentence 1    The overall accuracy of our gene expression cl...
# Sentence 2    A gene that warrants further studies is the er...
# Name: 42, dtype: object)
# (43, Sentence 1    A gene that warrants further studies is the er...
# Sentence 2    Another recent gene expression study of large ...
# Name: 43, dtype: object)
# (44, Sentence 1    MLL-FKBP and MLL-AF9 transformed cells showed ...
# Sentence 2    Regardless of the mechanism for transcriptiona...
# Name: 44, dtype: object)
# (45, Sentence 1    These findings were identical to the pattern o...
# Sentence 2    These genes are consistently expressed in leuk...
# Name: 45, dtype: object)
# (46, Sentence 1    miR-Vec constructs were described before, and ...
# Sentence 2    The pMSCV-blast-miR plasmids, containing eithe...
# Name: 46, dtype: object)
# (47, Sentence 1    For Sox11 repression by miR-204, Neuro-2a cell...
# Sentence 2    Co-transfection of miRVec-miR-204  and the Ren...
# Name: 47, dtype: object)
# (48, Sentence 1    Consequently miRNAs have been demonstrated to ...
# Sentence 2    The extent to which miRNAs specifically affect...
# Name: 48, dtype: object)
# (49, Sentence 1    Consequently miRNAs have been demonstrated to ...
# Sentence 2    Given the extensive involvement of miRNA in ph...
# Name: 49, dtype: object)
# (50, Sentence 1    In many tumors, there is either overexpression...
# Sentence 2    Of note, miR-373 had been previously identifie...
# Name: 50, dtype: object)
# (51, Sentence 1    To directly measure the effect of endogenous D...
# Sentence 2    The 3′UTRs of p27 and connexin-43 were PCR amp...
# Name: 51, dtype: object)
# (52, Sentence 1    These models have facilitated the identificati...
# Sentence 2    The development of genome-scale libraries of R...
# Name: 52, dtype: object)
# (53, Sentence 1    These cells (herein termed TLM-HMECs) are immo...
# Sentence 2    HMECs expressing hTERT and SV40 LT (TLM-HMECs)...
# Name: 53, dtype: object)
# (54, Sentence 1    Ironically, Rest has recently been described a...
# Sentence 2    REST is a transcription factor that represses ...
# Name: 54, dtype: object)
# (55, Sentence 1    Further, INPP4B was identified out of a collec...
# Sentence 2    On the other hand, RASA4/CAPRI (RAS p21 protei...
# Name: 55, dtype: object)
# (56, Sentence 1    Alterations in Oct-4 expression promote differ...
# Sentence 2    Additionally, expression of OCT4 and SOX2 has ...
# Name: 56, dtype: object)
# (57, Sentence 1    T47D, MCF-7, Skbr3, HeLa, and Caco-2 cells wer...
# Sentence 2    MCF7 or HeLa cells were electroporated as desc...
# Name: 57, dtype: object)
# (58, Sentence 1    It has been shown, however, that ubiquitinatio...
# Sentence 2    APC-dependent degradation of cyclin D1 does no...
# Name: 58, dtype: object)
# (59, Sentence 1    A few studies have reported the control of APC...
# Sentence 2    In fact, genotoxic stresses such as ionizing r...
# Name: 59, dtype: object)
# (60, Sentence 1    As p16INK4a blocks the inactivation of pRb by ...
# Sentence 2    By inducing Arf and Ink4a in primary rodent fi...
# Name: 60, dtype: object)
# (61, Sentence 1    For the analysis of expression at different st...
# Sentence 2    We investigated the patterns of expression of ...
# Name: 61, dtype: object)
# (62, Sentence 1    Besides these 28 OCT4-regulated genes, the Oct...
# Sentence 2    Almost half (37) of the Oct4-OETN genes are kn...
# Name: 62, dtype: object)
# (63, Sentence 1    Expression of an activated form of Ras protein...
# Sentence 2    The senescent state has been observed to be in...
# Name: 63, dtype: object)
# (64, Sentence 1    Activated Ras will transform established lines...
# Sentence 2    Moreover, oncogenes such as H-RASV12 provoke a...
# Name: 64, dtype: object)
# (65, Sentence 1    Oct-4-dependent transcriptional networks have ...
# Sentence 2    Co-transfection of miRVec-miR-204  and the Ren...
# Name: 65, dtype: object)
# (66, Sentence 1    This oxidative branch activity is elevated in ...
# Sentence 2    The Downward laboratory  went all the way from...
# Name: 66, dtype: object)
# (67, Sentence 1    Accordingly, expression of mutant K-Ras alone ...
# Sentence 2    the results of research  represent a very impo...
# Name: 67, dtype: object)
# (68, Sentence 1    Considerable evidence indicates that cancer ce...
# Sentence 2    In the case of cell response to stress, cyclin...
# Name: 68, dtype: object)
# (69, Sentence 1    In PC9 cells, loss of GATA6 and/or HOPX did no...
# Sentence 2    It has been shown that the activities of many ...
# Name: 69, dtype: object)
# (70, Sentence 1    A recent study identified the importance of th...
# Sentence 2    Alternatively, the anaphase promoting complex ...
# Name: 70, dtype: object)
# (71, Sentence 1    The researchers screened human NSCLC cell line...
# Sentence 2    Recently, it was shown that Gata2 fulfills suc...
# Name: 71, dtype: object)
# (72, Sentence 1    A number of studies have identified unbiased s...
# Sentence 2    This would also permit the use of inhibitors t...
# Name: 72, dtype: object)
# (73, Sentence 1    Finally, researchers combined available inhibi...
# Sentence 2    In PC9 cells, loss of GATA6 and/or HOPX did no...
# Name: 73, dtype: object)
# (74, Sentence 1    They identified that some genes involved in RH...
# Sentence 2    The researchers combined available inhibitors ...
# Name: 74, dtype: object)
# (75, Sentence 1    The in vivo data is still preliminary and othe...
# Sentence 2    The GEM model used in this study retains wild-...
# Name: 75, dtype: object)
# (76, Sentence 1    In spite of these caveats, the results of rese...
# Sentence 2    We should consider the data of research as an ...
# Name: 76, dtype: object)
# (77, Sentence 1    Here, looking for agents that could specifical...
# Sentence 2    Not surprisingly, GATA2 knockdown in KRAS muta...
# Name: 77, dtype: object)
# (78, Sentence 1    In lung tumors, TRAF6 levels can become elevat...
# Sentence 2    GATA2lox/lox   Sporadic infection of lung cell...
# Name: 78, dtype: object)
# (79, Sentence 1    GATA2 is also of considerable interest; geneti...
# Sentence 2    The GATA2 transcription factor, which is essen...
# Name: 79, dtype: object)
# (80, Sentence 1    BAF53 and β-actin subunits have been implicate...
# Sentence 2    β-actin and actin-related proteins have been f...
# Name: 80, dtype: object)
# (81, Sentence 1    Third, human Wts2 is a phosphorylation target ...
# Sentence 2    Similarly to PLK1, Aurora-A activity is requir...
# Name: 81, dtype: object)
# (82, Sentence 1    Changes in miR-146a and miR-146b expression an...
# Sentence 2    Additionally, loss of LATS2 stimulated redupli...
# Name: 82, dtype: object)
# (83, Sentence 1    We found no obvious effect of LATS2-depletion ...
# Sentence 2    Among them, miR-143, miR-145 and miR-34a have ...
# Name: 83, dtype: object)
# (84, Sentence 1    Oct-4-dependent transcriptional networks have ...
# Sentence 2    One study reports upregulation of this miR as ...
# Name: 84, dtype: object)
# (85, Sentence 1    In addition, genetic and functional studies su...
# Sentence 2    In addition, up-regulation of miR-24 has also ...
# Name: 85, dtype: object)
# (86, Sentence 1    In PC9 cells, loss of GATA6 and/or HOPX did no...
# Sentence 2    Aurora-A is required for the correct localisat...
# Name: 86, dtype: object)
# (87, Sentence 1    Centrosomes increase both in size and in micro...
# Sentence 2    Functional studies showed that, when introduce...
# Name: 87, dtype: object)
# (88, Sentence 1    With respect to LATS2, it has been reported th...
# Sentence 2    The expression of miR-146a has been found to b...
# Name: 88, dtype: object)
# (89, Sentence 1    The up-regulation of miR-146a was also detecte...
# Sentence 2    Similarly to PLK1, Aurora-A activity is requir...
# Name: 89, dtype: object)
# (90, Sentence 1    Necroptosis is also part of host defense again...
# Sentence 2    Necrotic death was augmented when caspase acti...
# Name: 90, dtype: object)
# (91, Sentence 1    Necrotic death was augmented when caspase acti...
# Sentence 2    Intriguingly, in the presence of caspase inhib...
# Name: 91, dtype: object)
# (92, Sentence 1    The cyclin-dependent kinase (CDK) inhibitor ro...
# Sentence 2    Recent work in model systems and acute myeloge...
# Name: 92, dtype: object)
# (93, Sentence 1    The up-regulation of miR-146a was also detecte...
# Sentence 2    The expression of miR-146a has been found to b...
# Name: 93, dtype: object)
# (94, Sentence 1    At the onset of mitosis, LATS2 is activated by...
# Sentence 2    Lats2/Kpm is homologous to Lats1 and undergoes...
# Name: 94, dtype: object)
# (95, Sentence 1    Ironically, Rest has recently been described a...
# Sentence 2    In human epithelial cells REST has been descri...
# Name: 95, dtype: object)
# (96, Sentence 1    Alterations in Oct-4 expression promote differ...
# Sentence 2    OCT4, a transcript of POU5F1, plays a role in ...
# Name: 96, dtype: object)
# (97, Sentence 1    Three programs, PicTar, miRanda, and TargetSca...
# Sentence 2    The genes that decreased 2-fold or more were f...
# Name: 97, dtype: object)
# (98, Sentence 1    The recent reports demonstrated that the first...
# Sentence 2    Mismatches near the 5′ end of the small RNA co...
# Name: 98, dtype: object)
# (99, Sentence 1       Oncogenic KRAS mutations are common in cancer.
# Sentence 2    Notably, c-Raf has recently been found essenti...
# Name: 99, dtype: object)
